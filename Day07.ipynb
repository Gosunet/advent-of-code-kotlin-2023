// %%
import kotlin.io.path.Path
import kotlin.io.path.readLines

val input = Path("src/day07.txt").readLines()

// %%
enum class HandType {
  HIGH,
  PAIR,
  PAIRS,
  TRIPLE,
  FULL,
  FOUR,
  FIVE,
}

val winningCardOrder = listOf("A", "K", "Q", "J", "T", "9", "8", "7", "6", "5", "4", "3", "2")
data class Hand(val cards: String, val bid: Long): Comparable<Hand> {
  val handType: HandType = cards.groupingBy { it }.eachCount().let {
    when {
      it.any { it.value == 5 } -> HandType.FIVE
      it.any { it.value == 4 } -> HandType.FOUR
      it.any { it.value == 3} -> {
        if (it.count() == 2) HandType.FULL else HandType.TRIPLE
      }
      it.any { it.value == 2 } -> {
        if (it.count() == 3) HandType.PAIRS else HandType.PAIR
      }
      else -> HandType.HIGH
    }
  }
  
  override fun compareTo(other: Hand): Int {
    return if (this.handType != other.handType) this.handType.compareTo(other.handType)
    else {
      for (i in 0..this.cards.length) {
        if (this.cards[i] == other.cards[i]) {
          continue
        } else {
          val indexThis = winningCardOrder.indexOf(this.cards[i].toString())
          val indexOther = winningCardOrder.indexOf(other.cards[i].toString())
          return indexOther.compareTo(indexThis)
        }
      }
      0
    }
  }
}

// %%
val hands = input.map { 
  val (hands, bid) = it.split(" ").filter { it.isNotBlank() }
  Hand(hands, bid.toLong())
}

// %%
%use kandy

// %%
hands.sorted()
// Out:
// [Hand(cards=237T5, bid=711), Hand(cards=23KQ6, bid=432), Hand(cards=245QK, bid=521), Hand(cards=25QJA, bid=946), Hand(cards=264AJ, bid=996), Hand(cards=269J8, bid=512), Hand(cards=26A9J, bid=635), Hand(cards=2783J, bid=243), Hand(cards=27865, bid=752), Hand(cards=278A3, bid=827), Hand(cards=2TJ7A, bid=229), Hand(cards=2J834, bid=854), Hand(cards=2JK74, bid=906), Hand(cards=2JAQK, bid=537), Hand(cards=2QKT5, bid=94), Hand(cards=32568, bid=673), Hand(cards=32T9A, bid=587), Hand(cards=34T9Q, bid=757), Hand(cards=35ATJ, bid=289), Hand(cards=37T2A, bid=355), Hand(cards=37J6T, bid=897), Hand(cards=38KA5, bid=431), Hand(cards=39J7A, bid=858), Hand(cards=3T5J6, bid=488), Hand(cards=3TQ4A, bid=63), Hand(cards=3TAJ8, bid=26), Hand(cards=3J748, bid=641), Hand(cards=3JT48, bid=38), Hand(cards=3Q294, bid=370), Hand(cards=3Q489, bid=185), Hand(cards=3Q869, bid=904), Hand(cards=3QK24, bid=760), Hand(cards=3K2AQ, bid=103), Hand(cards=3K6Q7, bid=433), Hand(cards=3KA7Q, bid=224), Hand(cards=3A62J, bid=654), Hand(cards=3A746, bid=633), Hand(cards=42KT7, bid=896), Hand(cards=43895, bid=922), Hand(cards=45296, bid=317), Hand(cards=4567T, bid=670), Hand(cards=46589, bid=934), Hand(cards=46Q75, bid=981), Hand(cards=47958, bid=799), Hand(cards=4T29Q, bid=101), Hand(cards=4T3KJ, bid=417), Hand(cards=4J5A6, bid=754), Hand(cards=4J829, bid=620), Hand(cards=4KQ5A, bid=550), Hand(cards=4A72T, bid=445), Hand(cards=4A7QJ, bid=950), Hand(cards=529A3, bid=344), Hand(cards=567JT, bid=506), Hand(cards=5746A, bid=971), Hand(cards=58642, bid=643), Hand(cards=589A4, bid=369), Hand(cards=59T28, bid=53), Hand(cards=59J2Q, bid=310), Hand(cards=59Q3T, bid=69), Hand(cards=59K7J, bid=32), Hand(cards=5T83K, bid=352), Hand(cards=5J6Q4, bid=698), Hand(cards=5J924, bid=255), Hand(cards=5JT82, bid=414), Hand(cards=5A3QK, bid=692), Hand(cards=5A837, bid=814), Hand(cards=5A87T, bid=285), Hand(cards=6257Q, bid=862), Hand(cards=62KAJ, bid=907), Hand(cards=63529, bid=272), Hand(cards=63TQ7, bid=990), Hand(cards=64293, bid=966), Hand(cards=64TA9, bid=382), Hand(cards=684KT, bid=678), Hand(cards=687Q3, bid=570), Hand(cards=68A2K, bid=867), Hand(cards=69A35, bid=201), Hand(cards=69A5K, bid=280), Hand(cards=6J524, bid=918), Hand(cards=6K4QA, bid=778), Hand(cards=6KTQJ, bid=840), Hand(cards=6A3T8, bid=739), Hand(cards=6A9T3, bid=435), Hand(cards=6AT23, bid=276), Hand(cards=6AQT9, bid=278), Hand(cards=6AK27, bid=727), Hand(cards=72A68, bid=106), Hand(cards=738K9, bid=943), Hand(cards=743KT, bid=924), Hand(cards=74AK2, bid=253), Hand(cards=75J8A, bid=434), Hand(cards=75JA9, bid=718), Hand(cards=768TJ, bid=284), Hand(cards=76J94, bid=461), Hand(cards=789AJ, bid=921), Hand(cards=78T53, bid=195), Hand(cards=78K69, bid=770), Hand(cards=795TQ, bid=389), Hand(cards=7T264, bid=40), Hand(cards=7J68K, bid=699), Hand(cards=7JT29, bid=657), Hand(cards=7K93A, bid=443), Hand(cards=7KJ4T, bid=480), Hand(cards=7KQ53, bid=456), Hand(cards=7KA83, bid=142), Hand(cards=7A965, bid=368), Hand(cards=82593, bid=825), Hand(cards=853AJ, bid=830), Hand(cards=8632Q, bid=905), Hand(cards=8634T, bid=303), Hand(cards=8637A, bid=197), Hand(cards=86T5A, bid=628), Hand(cards=87J53, bid=450), Hand(cards=89K46, bid=768), Hand(cards=89AJT, bid=809), Hand(cards=8TA4Q, bid=415), Hand(cards=8K56T, bid=233), Hand(cards=8A345, bid=119), Hand(cards=8AJ7Q, bid=83), Hand(cards=92438, bid=217), Hand(cards=92T8Q, bid=181), Hand(cards=92J78, bid=686), Hand(cards=92KQ5, bid=889), Hand(cards=93J78, bid=463), Hand(cards=965T3, bid=41), Hand(cards=96Q4T, bid=552), Hand(cards=9T374, bid=638), Hand(cards=9T874, bid=49), Hand(cards=9TK4A, bid=826), Hand(cards=9J758, bid=492), Hand(cards=9JK25, bid=12), Hand(cards=9Q637, bid=55), Hand(cards=9QAK8, bid=312), Hand(cards=9K437, bid=228), Hand(cards=9K482, bid=390), Hand(cards=9A357, bid=828), Hand(cards=T2847, bid=583), Hand(cards=T3J47, bid=656), Hand(cards=T4A32, bid=198), Hand(cards=T6JA5, bid=543), Hand(cards=T78J9, bid=353), Hand(cards=T7QK9, bid=994), Hand(cards=T7K5Q, bid=833), Hand(car ...

// %%
hands.sorted().withIndex().sumOf { (index, value) ->
  println()
  value.bid * (index + 1)
 }
// Out:
// 249390788
